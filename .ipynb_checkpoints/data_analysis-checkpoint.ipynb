# %%
from pathlib import Path
import subprocess

import pandas as pd

# %%
# import sys
# print(sys.executable)
# Out:
# /home/aditya/dev-work/video-captioning-agent/.venv/bin/python3

# %%
# import numpy
# import pandas
# import matplotlib

# print("NumPy:", numpy.__version__)
# print("Pandas:", pd.__version__)
# print("Matplotlib:", matplotlib.__version__)
# Out:
# NumPy: 2.5.1
# Pandas: 3.0.3
# Matplotlib: 3.11.0

# %%
ROOT_DIR = Path("/home/aditya/dev-work/video-captioning-agent/Data/Charades_v1_480/Charades_v1_480")

# %%
VIDEO_EXTENSIONS = {
    ".mp4", ".avi", ".mov", ".mkv", ".webm",
    ".mpeg", ".mpg", ".m4v", ".wmv", ".flv", ".3gp"
}

# %%
def get_duration(video_path: Path):
    try:
        result = subprocess.run(
            [
                "ffprobe",
                "-v", "error",
                "-show_entries", "format=duration",
                "-of", "default=noprint_wrappers=1:nokey=1",
                str(video_path),
            ],
            capture_output=True,
            text=True,
            check=True,
        )
        return float(result.stdout.strip())
    except Exception:
        return None

# %%
records = []

print("Scanning...")

from tqdm import tqdm

for video in tqdm(ROOT_DIR.rglob("*"), desc="Scanning videos"):
    if not video.is_file():
        continue

    if video.suffix.lower() not in VIDEO_EXTENSIONS:
        continue

    duration = get_duration(video)
    if duration is None:
        continue

    records.append({
        "class": video.parent.name,
        "filename": video.name,
        "duration_sec": duration,
        "path": str(video),
    })
# Out:
# Scanning...
# Scanning videos: 9848it [10:52, 15.09it/s]

# %%
df = pd.DataFrame(records)

print("\n===== Overall Statistics =====")
print(df["duration_sec"].describe())

print("\nShortest videos:")
print(df.nsmallest(10, "duration_sec")[["duration_sec", "path"]])

print("\nLongest videos:")
print(df.nlargest(10, "duration_sec")[["duration_sec", "path"]])
# Out:
# ===== Overall Statistics =====
# count    9848.000000
# mean       29.741589
# std         9.182399
# min         2.368005
# 25%        26.889501
# 50%        30.650000
# 75%        32.299002
# max       194.397007
# Name: duration_sec, dtype: float64
#
# Shortest videos:
#       duration_sec                                               path
# 3895      2.368005  /home/aditya/dev-work/video-captioning-agent/D...
# 5845      2.577007  /home/aditya/dev-work/video-captioning-agent/D...
# 6435      2.600000  /home/aditya/dev-work/video-captioning-agent/D...
# 9046      2.648045  /home/aditya/dev-work/video-captioning-agent/D...
# 4249      2.879002  /home/aditya/dev-work/video-captioning-agent/D...
# 2602      2.880000  /home/aditya/dev-work/video-captioning-agent/D...
# 6658      2.949002  /home/aditya/dev-work/video-captioning-agent/D...
# 3595      3.088005  /home/aditya/dev-work/video-captioning-agent/D...
# 4376      3.158005  /home/aditya/dev-work/video-captioning-agent/D...
# 7143      3.203991  /home/aditya/dev-work/video-captioning-agent/D...
#
# Longest videos:
#       duration_sec                                               path
# 6985    194.397007  /home/aditya/dev-work/video-captioning-agent/D...
# 7680    178.491995  /home/aditya/dev-work/video-captioning-agent/D...
# 9138    161.820000  /home/aditya/dev-work/video-captioning-agent/D...
# 2110    160.682166  /home/aditya/dev-work/video-captioning-agent/D...
# 1904    157.500998  /home/aditya/dev-work/video-captioning-agent/D...
# 9812    137.113991  /home/aditya/dev-work/video-captioning-agent/D...
# 686     135.836009  /home/aditya/dev-work/video-captioning-agent/D...
# 8579    129.380998  /home/aditya/dev-work/video-captioning-agent/D...
# 7456    128.638998  /home/aditya/dev-work/video-captioning-agent/D...
# 1454    127.106788  /home/aditya/dev-work/video-captioning-agent/D...

# %%
import matplotlib.pyplot as plt

df["duration_sec"].hist(bins=50)

plt.xlabel("Duration (seconds)")
plt.ylabel("Number of videos")
plt.title("Video Duration Distribution")
plt.show()

# %%
valid = df[
    (df["duration_sec"] >= 30) &
    (df["duration_sec"] <= 120)
]

print(len(valid))
print(f"{100 * len(valid) / len(df):.2f}%")
# Out:
# 6089
# 61.83%

# %%
print(
    df["duration_sec"]
      .round(1)
      .value_counts()
      .head(20)
)
# Out:
# duration_sec
# 30.6    287
# 31.0    274
# 30.7    257
# 30.8    248
# 30.5    216
# 30.3    206
# 30.4    193
# 31.3    190
# 31.1    177
# 30.9    159
# 31.6    144
# 30.0    138
# 30.1    134
# 32.0    129
# 31.4    121
# 30.2    121
# 31.2    111
# 29.8    104
# 31.8    103
# 31.5    103
# Name: count, dtype: int64

# %%
# Write paths of videos with duration in [30, 120] seconds to a text file
output_txt = Path("valid_videos_30_120s.txt")

valid = df[(df["duration_sec"] >= 30) & (df["duration_sec"] <= 120)].copy()
print(f"Found {len(valid)} videos in range [30, 120] seconds "
      f"({100 * len(valid) / len(df):.2f}% of {len(df)}).")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Write paths of videos with duration in [30, 120] seconds to a text file
# ----> 2 output_txt = Path("valid_videos_30_120s.txt")
#       3
#       4 valid = df[(df["duration_sec"] >= 30) & (df["duration_sec"] <= 120)].copy()
#       5 print(f"Found {len(valid)} videos in range [30, 120] seconds "
#
# NameError: name 'Path' is not defined

# %%
# Option 1: plain Python (newline-separated, sorted by filename for reproducibility)
valid_sorted = valid.sort_values("path")
with output_txt.open("w", encoding="utf-8") as f:
    for p in valid_sorted["path"]:
        f.write(p + "\n")

print(f"Wrote {len(valid_sorted)} paths to: {output_txt.resolve()}")

# %%
# Quick sanity check: read back and count lines
with output_txt.open("r", encoding="utf-8") as f:
    line_count = sum(1 for _ in f if _.strip())
print(f"Verified line count in file: {line_count}")
